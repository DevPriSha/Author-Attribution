# %% [markdown]
# # ML/DL Project: Colab Notebook for EDA and Training

# %% [markdown]
# **__Team ID:__** 22
#
# **__Team Members:__** Priya Sharma, Apoorva Verma, Vidhi Khubchandani
#
# **__Project Title:__** Author Identification using Discord text messages

# %%
# import stuff
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %%
pcf_gen = pd.read_csv("./Data/pcf-general.csv")
spl_gen_1 = pd.read_csv("./Data/spl-gen-1.csv")
spl_gen_2 = pd.read_csv("./Data/spl-gen-2.csv")

# %%
# appending spl_gen_2 to spl_gen_1
spl_gen = pd.concat([spl_gen_1, spl_gen_2], axis=0, ignore_index=True)

# %% [markdown]
# ## 1. Exploratory Data Analyis

# %%
spl_gen
# Out:
#                  AuthorID                       Author                Date  \
# 0      495167666726895616  ( ˶ᵔ༝ᵔ˶) milquetoast ♡#1999  05-Sep-20 12:35 AM
# 1      442393544376975380                   Raven#5888  05-Sep-20 12:35 AM
# 2      495167666726895616  ( ˶ᵔ༝ᵔ˶) milquetoast ♡#1999  05-Sep-20 12:35 AM
# 3      362299347729121281                Brohepsi#1599  05-Sep-20 12:41 AM
# 4      692342743418142801                𝙁𝙞𝙧𝙚𝙬𝙤𝙧𝙠#2551  05-Sep-20 12:41 AM
# ...                   ...                          ...                 ...
# 94802  106634422022860800          MaralinaSakura#1304  25-Sep-22 02:02 AM
# 94803  707303192257626164                   Metta#2122  25-Sep-22 05:35 AM
# 94804  495167666726895616  ( ˶ᵔ༝ᵔ˶) milquetoast ♡#1999  25-Sep-22 07:03 AM
# 94805  707303192257626164                   Metta#2122  25-Sep-22 07:07 AM
# 94806  757599193614254141            Akuna Matata#7251  25-Sep-22 10:47 AM
#
#                                                  Content  \
# 0       HELLO thank you for inviting and accepting me!!!
# 1                                                      🤗
# 2                    wow it’s just like the old server 😳
# 3      Thanks for doing this so much. You've made my ...
# 4                                   I'm glad to hear it.
# ...                                                  ...
# 94802                          Like early 40s at *worst*
# 94803                        oh hey another TCH ad by PB
# 94804                        I thought tch2 :pepesadboi:
# 94805                                        Soon enough
# 94806                      ~~*seals the curse instead*~~
#
#                                              Attachments Reactions
# 0                                                    NaN       NaN
# 1                                                    NaN       NaN
# 2                                                    NaN       NaN
# 3                                                    NaN       NaN
# 4                                                    NaN       NaN
# ...                                                  ...       ...
# 94802                                                NaN       NaN
# 94803  https://cdn.discordapp.com/attachments/7514700...       NaN
# 94804                                                NaN       NaN
# 94805                                                NaN       NaN
# 94806                                                NaN       NaN
#
# [94807 rows x 6 columns]

# %%
pcf_gen
# Out:
#                   AuthorID           Author                Date  \
# 0       265899192373870592     KaiaLou#7681  20-May-18 08:00 AM
# 1       292140230729924608        Kaii#9972  20-May-18 08:00 AM
# 2       265899192373870592     KaiaLou#7681  20-May-18 08:02 AM
# 3       265899192373870592     KaiaLou#7681  20-May-18 08:02 AM
# 4       292140230729924608        Kaii#9972  20-May-18 08:02 AM
# ...                    ...              ...                 ...
# 356946  692342743418142801    𝙁𝙞𝙧𝙚𝙬𝙤𝙧𝙠#2551  26-Sep-22 12:00 PM
# 356947  310882928752328735  Belbercike#4557  26-Sep-22 12:31 PM
# 356948  301372241176952832       azula#9750  26-Sep-22 12:49 PM
# 356949  301372241176952832       azula#9750  26-Sep-22 12:50 PM
# 356950  397356894127390720  Rayvenrock#2954  26-Sep-22 01:44 PM
#
#                                                   Content  \
# 0                                 Anyone played Chapters?
# 1                                                    Yeah
# 2           This peep said one time about the diamonds...
# 3       *walk away* - costs diamonds \n*insult her mot...
# 4                                                    LOLL
# ...                                                   ...
# 356946                         you should look at the abs
# 356947            to compensate, his waist isn't snatched
# 356948  Stepped in a puddle and ruined my AF1s my day ...
# 356949                     Now one is clean and one isn't
# 356950                                             nuuuu]
#
#                                               Attachments Reactions
# 0                                                     NaN       NaN
# 1                                                     NaN       NaN
# 2                                                     NaN       NaN
# 3                                                     NaN       NaN
# 4                                                     NaN       NaN
# ...                                                   ...       ...
# 356946                                                NaN       NaN
# 356947                                                NaN       NaN
# 356948  https://cdn.discordapp.com/attachments/4475818...       NaN
# 356949  https://cdn.discordapp.com/attachments/4475818...       NaN
# 356950                                                NaN       NaN
#
# [356951 rows x 6 columns]

# %%
# list of all authorID common to both dataframes
authorID = list(set(pcf_gen['AuthorID']).intersection(set(spl_gen['AuthorID'])))
print(authorID)
print("No. of users common to both servers: ", len(authorID))
# Out:
# [495167666726895616, 362299347729121281, 106634422022860800, 172002275412279296, 456226577798135808, 308738655223152642, 301244564188954624, 261850654400708610, 275617570852438016, 283193899336335360, 306541680419405826, 363091160027103243, 451747664472571907, 622656139389042699, 263855609709854721, 201796440576491521, 439205512425504771, 488049679976759305, 434821263354232843, 760937074118885387, 442393544376975380, 297003997322280981, 580349344633585684, 542162907333525508, 742154890804985876, 366565198284324868, 658082229469184020, 640567496314716180, 831172293945720852, 364570774717071361, 406327286145744926, 492599210357555201, 310882928752328735, 517501633374978079, 564667779181969409, 873569055733329951, 235088799074484224, 211534205862150144, 155149108183695360, 739848819323305984, 617378411652055080, 625369267008700456, 197929627728084992, 397356894127390720, 395640703704891392, 301372241176952832, 373187896699781120, 85614143951892480, 607327540893188144, 786672447935348737, 703729271788535858, 806489789574545458, 707303192257626164, 771929460261650482, 221687883852021770, 757599193614254141, 899901520701714493, 517453558082306120, 707992538082181322, 692342743418142801, 301672529561518081, 224246014473797633, 173889000015134720, 500837646805893121, 221750480257155072, 752560019131859046, 423943858813140993]
# No. of users common to both servers:  67

# %%
#create a dataframe with AuthorID and the number of content in each server
df = pd.DataFrame(columns=['AuthorID', 'Author', 'pcf_gen', 'spl_gen'])
df['AuthorID'] = authorID
#find author name for each authorID
df['Author'] = df['AuthorID'].apply(lambda x: pcf_gen[pcf_gen['AuthorID'] == x]['Author'].values[0])
df['pcf_gen'] = df['AuthorID'].apply(lambda x: pcf_gen[pcf_gen['AuthorID'] == x].shape[0])
df['spl_gen'] = df['AuthorID'].apply(lambda x: spl_gen[spl_gen['AuthorID'] == x].shape[0])
#sort df by sum of content in both servers
df = df.sort_values(by=['pcf_gen', 'spl_gen'], ascending=False)
df
# Out:
#               AuthorID               Author  pcf_gen  spl_gen
# 45  301372241176952832           azula#9750    43252        1
# 60  301672529561518081             oge#1004    32931        5
# 44  395640703704891392     DaHomieDrew#3237    24917     8069
# 61  224246014473797633             kyo#5036    22958       29
# 20  442393544376975380           Raven#5888    22479      252
# ..                 ...                  ...      ...      ...
# 63  500837646805893121     natatouille#5197        1       38
# 40  617378411652055080     lion_raider#2667        1       13
# 35  873569055733329951  James Hametson#9998        1        6
# 11  363091160027103243     quicksilver#9237        1        3
# 51  806489789574545458    Hell-Volhard#4976        1        1
#
# [67 rows x 4 columns]

# %%
#save df to csv
df.to_csv("./Data/common-users.csv", index=False)

# %%
#plot the number of content in each server
plt.figure(figsize=(10, 5))
plt.bar(df['Author'], df['pcf_gen'], label='pcf_gen')
plt.bar(df['Author'], df['spl_gen'], bottom=df['pcf_gen'], label='spl_gen')
plt.xticks(rotation=90)
plt.legend()
plt.show()

# %%
# plot the number of content in pcf_gen by common users
plt.figure(figsize=(10, 5))
plt.bar(df['Author'], df['pcf_gen'], label='pcf_gen')
plt.xticks(rotation=90)
plt.legend()
plt.show()

# %%
# plot the number of content in spl_gen by common users
plt.figure(figsize=(10, 5))
plt.bar(df['Author'], df['spl_gen'], label='spl_gen')
plt.xticks(rotation=90)
plt.legend()
plt.show()

# %%
from wordcloud import WordCloud, STOPWORDS
stopwords = set(STOPWORDS)
stopwords.add("s")
stopwords.add("t")
stopwords.add("m")
stopwords.add("one")
stopwords.add("ll")
stopwords.add("ve")
stopwords.add("re")


def black_color_func(word, font_size, position,orientation,random_state=None, **kwargs):
    return("hsl(0,100%, 1%)")

#create wordcloud for each user in pcf_gen

for author in authorID:
    author_name = pcf_gen[pcf_gen['AuthorID'] == author]['Author'].values[0]
    author_name = ''.join(e for e in author_name if e.isalnum())
    text = pcf_gen[pcf_gen['AuthorID'] == author]['Content'].str.cat(sep=' ')
    try:
        wordcloud = WordCloud(stopwords=stopwords, background_color="white", contour_width=3, contour_color='steelblue', width=1000, height=500).generate(text)
        wordcloud.recolor(color_func=black_color_func)
        wordcloud.to_file("D:\Downloads\Author_Attribution\wordclouds\pcf_gen\{}.png".format(author_name))
    except:
        pass

#create wordcloud for each user in spl_gen

for author in authorID:
    author_name = spl_gen[spl_gen['AuthorID'] == author]['Author'].values[0]
    author_name = ''.join(e for e in author_name if e.isalnum())
    text = spl_gen[spl_gen['AuthorID'] == author]['Content'].str.cat(sep=' ')
    try:
        wordcloud = WordCloud(stopwords=stopwords, background_color="white", contour_width=3, contour_color='steelblue', width=1000, height=500).generate(text)
        wordcloud.recolor(color_func=black_color_func)
        wordcloud.to_file("D:\Downloads\Author_Attribution\wordclouds\spl_gen\{}.png".format(author_name))
    except:
        pass
